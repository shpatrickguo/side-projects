# %% [markdown]
# # Taiwan ADIZ Violations

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd

# %% [markdown]
# ## Load Data

# %%
sheet_id = "1qbfYF0VgDBJoFZN5elpZwNTiKZ4nvCUcs5a7oYwm52g"
sheet_url = f"https://docs.google.com/spreadsheets/d/{sheet_id}/export?gid=0&format=csv"
df = pd.read_csv(sheet_url)

# %% [markdown]
# # EDA

# %%
df.head()
# Out:
#         Date  Year  Month  Day  lookup Day of Week      Category  \
# 0   9/9/2020  2020      9    9       4   Wednesday  *Unspecified
# 1  9/10/2020  2020      9   10       5    Thursday  *Unspecified
# 2  9/16/2020  2020      9   16       4   Wednesday           ASW
# 3  9/18/2020  2020      9   18       6      Friday        Bomber
# 4  9/18/2020  2020      9   18       6      Friday       Fighter
#
#   Aircraft Type  # of Aircraft        Location  Tail Numbers Unnamed: 11  \
# 0  *Unspecified             10             unk           NaN         NaN
# 1  *Unspecified             11             unk           NaN         NaN
# 2       Y-8 ASW              2  Southwest ADIZ           NaN         NaN
# 3           H-6              2  Southwest ADIZ           NaN         NaN
# 4          J-16              4  Southwest ADIZ           NaN         NaN
#
#                                                Notes  \
# 0  unspecified mix of SU-30 and J-10, 21 total vi...
# 1  unspecified mix of SU-30 and Y-8, 21 total vio...
# 2                                                NaN
# 3                                                NaN
# 4  assumed equal split of total sorties for south...
#
#                                               Source
# 0  https://www.mnd.gov.tw/English/Publish.aspx?ti...
# 1  https://www.mnd.gov.tw/English/Publish.aspx?ti...
# 2  https://www.mnd.gov.tw/Publish.aspx?p=77345&ti...
# 3  https://www.mnd.gov.tw/Publish.aspx?p=77350&ti...
# 4  https://www.mnd.gov.tw/Publish.aspx?p=77350&ti...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 663 entries, 0 to 662
# Data columns (total 14 columns):
# Date             663 non-null object
# Year             663 non-null int64
# Month            663 non-null int64
# Day              663 non-null int64
# lookup           663 non-null int64
# Day of Week      663 non-null object
# Category         663 non-null object
# Aircraft Type    663 non-null object
# # of Aircraft    663 non-null int64
# Location         663 non-null object
# Tail Numbers     6 non-null float64
# Unnamed: 11      2 non-null object
# Notes            122 non-null object
# Source           663 non-null object
# dtypes: float64(1), int64(5), object(8)
# memory usage: 72.6+ KB

# %%
df.describe()
# Out:
#               Year       Month         Day      lookup  # of Aircraft  \
# count   663.000000  663.000000  663.000000  663.000000     663.000000
# mean   2020.891403    7.453997   16.049774    3.951735       1.906486
# std       0.482599    3.956017    8.667347    1.965893       2.480194
# min    2020.000000    1.000000    1.000000    1.000000       1.000000
# 25%    2021.000000    4.000000    9.000000    2.000000       1.000000
# 50%    2021.000000    9.000000   17.000000    4.000000       1.000000
# 75%    2021.000000   11.000000   23.000000    6.000000       2.000000
# max    2022.000000   12.000000   31.000000    7.000000      34.000000
#
#        Tail Numbers
# count      6.000000
# mean   38874.333333
# std    34341.216272
# min     9231.000000
# 25%    11983.500000
# 50%    25378.000000
# 75%    69137.750000
# max    82016.000000

# %%
df.isna().sum()
# Out:
# Date               0
# Year               0
# Month              0
# Day                0
# lookup             0
# Day of Week        0
# Category           0
# Aircraft Type      0
# # of Aircraft      0
# Location           0
# Tail Numbers     657
# Unnamed: 11      661
# Notes            541
# Source             0
# dtype: int64

# %%
df.to_csv("adiz_violations.csv")
